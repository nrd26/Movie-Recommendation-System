# %% [markdown]
# ### My Approach

# %% [markdown]
# Making a movie reccomendation system has been on my to-do list since the past month or so but I never got around to trying it out. Glad a got this chance to try out something new :)
#
# So first of all I checked out a few online resources like a few articles and a few YouTube videos and they mostly used the TMDB 5000 dataset(https://www.kaggle.com/tmdb/tmdb-movie-metadata) so I went ahead with the same because I got more accustomed to the dataset.
#
# The credits dataset contains the following features:-
#
#     movie_id - A unique identifier for each movie.
#     cast - The name of lead and supporting actors.
#     crew - The name of Director, Editor, Composer, Writer etc.
#
# The movie dataset has the following features:-
#
#     budget - The budget in which the movie was made.
#     genre - The genre of the movie, Action, Comedy ,Thriller etc.
#     homepage - A link to the homepage of the movie.
#     id - This is infact the movie_id as in the first dataset.
#     keywords - The keywords or tags related to the movie.
#     original_language - The language in which the movie was made.
#     original_title - The title of the movie before translation or adaptation.
#     overview - A brief description of the movie.
#     popularity - A numeric quantity specifying the movie popularity.
#     production_companies - The production house of the movie.
#     production_countries - The country in which it was produced.
#     release_date - The date on which it was released.
#     revenue - The worldwide revenue generated by the movie.
#     runtime - The running time of the movie in minutes.
#     status - "Released" or "Rumored".
#     tagline - Movie's tagline.
#     title - Title of the movie.
#     vote_average - average ratings the movie recieved.
#     vote_count - the count of votes recieved.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ### Reading Data

# %%
data=pd.read_csv('tmdb_5000_movies.csv')
data1=pd.read_csv('tmdb_5000_credits.csv')

# %%
data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %%
data1.head()
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
# 2    206647                                   Spectre
# 3     49026                     The Dark Knight Rises
# 4     49529                               John Carter
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# ...

# %% [markdown]
# ### Merging the datasets
# Since it's a lot easier to just work with 1 dataset, I just merged both of them

# %%
data1.columns = ['id','tittle','cast','crew']
data= data.merge(data1,on='id')

# %%
data.head()
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2  245000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3  250000000  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4  260000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
#
#                                        homepage      id  \
# 0                   http://www.avatarmovie.com/   19995
# 1  http://disney.go.com/disneypictures/pirates/     285
# 2   http://www.sonypictures.com/movies/spectre/  206647
# 3            http://www.thedarkknightrises.com/   49026
# 4          http://movies.disney.com/john-carter   49529
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
# ...

# %% [markdown]
# ### Analysing the data
# Here we use literal_eval to check if our data is a python object or not(ast.literal_eval raises an exception if the input isn't a valid Python datatype, so the code won't be executed if it's not.)

# %%
from ast import literal_eval

features = ['cast', 'crew', 'keywords', 'genres']
for feature in features:
    data[feature] = data[feature].apply(literal_eval)

# %% [markdown]
# A simple function to get the Director's name from the crew list( returns NaN if there is no mention of the director)

# %%
def director(x):
    for i in x:
        if i['job'] == 'Director':
            return i['name']
    return np.nan

# %% [markdown]
# For using the data on cast, movie keywords and genre, we select the top 5(If there are >=5 elements in each category we return the top 5 else we return the entire list and return an empty list in case of missing data)

# %%
def top_features(x):
    if isinstance(x, list):
        names = [i['name'] for i in x]
        if len(names) > 5:
            names = names[:5]
        return names

    return []

# %% [markdown]
# We now extract the data we want from the data we have

# %%
data['director'] = data['crew'].apply(director)

features = ['cast', 'keywords', 'genres']
for feature in features:
    data[feature] = data[feature].apply(top_features)

# %%
# Print the new features
data[['title', 'cast', 'director', 'keywords', 'genres']].head()
# Out:
#                                       title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
# 3                     The Dark Knight Rises
# 4                               John Carter
#
#                                                 cast           director  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...      James Cameron
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...     Gore Verbinski
# 2  [Daniel Craig, Christoph Waltz, Léa Seydoux, R...         Sam Mendes
# 3  [Christian Bale, Michael Caine, Gary Oldman, A...  Christopher Nolan
# 4  [Taylor Kitsch, Lynn Collins, Samantha Morton,...     Andrew Stanton
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2   [spy, based on novel, secret agent, sequel, mi6]
# ...

# %% [markdown]
# This is a function to remove whitespaces and convert all strings to lowercase so that Python can differentiate between say for example a Chris Evans and a Chris Hemsworth and counts them as different entities(it returns an empty string if there's no info on the director)

# %%
def remove(x):
    if isinstance(x, list):
        return [str.lower(i.replace(" ", "")) for i in x]
    else:
        if isinstance(x, str):
            return str.lower(x.replace(" ", ""))
        else:
            return ''

# %%
features = ['cast', 'keywords', 'director', 'genres']

for feature in features:
    data[feature] = data[feature].apply(remove)

# %% [markdown]
# This function creates a string with all the metadata that we want

# %%
def result(x):
    return ' '.join(x['keywords']) + ' ' + ' '.join(x['cast']) + ' ' + x['director'] + ' ' + ' '.join(x['genres'])
data['result'] = data.apply(result, axis=1)

# %% [markdown]
# We now implement the CountVectorizer from sklearn to analyse the words

# %%
from sklearn.feature_extraction.text import CountVectorizer

count = CountVectorizer(stop_words='english')
count_matrix = count.fit_transform(data['result'])

# %% [markdown]
# The below code computes the cosine Similarity among the vectors

# %%
from sklearn.metrics.pairwise import cosine_similarity

cos_sim = cosine_similarity(count_matrix, count_matrix)

# %% [markdown]
# The below code resets the indices

# %%
data = data.reset_index()
indices = pd.Series(data.index, index=data['title'])

# %% [markdown]
# The below function takes in movie title as input and outputs most similar movies

# %%
indices = pd.Series(data.index, index=data['title']).drop_duplicates()

def find_rec(title, cos_sim=cos_sim):
    idx = indices[title]
    sim_scores = list(enumerate(cos_sim[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]
    movie_indices = [i[0] for i in sim_scores]

    return data['title'].iloc[movie_indices]

# %% [markdown]
# ### Testing
# So since the recommendation system is done, I tested it out on a couple of my favourite movies

# %%
find_rec('The Karate Kid')
# Out:
# 4333                          Rocky
# 4564       Straight Out of Brooklyn
# 3863                         August
# 3043               End of the Spear
# 4247          Me You and Five Bucks
# 4638       Amidst the Devil's Wings
# 2919                My Cousin Vinny
# 3134                      Partition
# 4228    The Ballad of Jack and Rose
# 1940                        Carnage
# Name: title, dtype: object

# %%
find_rec('Harry Potter and the Goblet of Fire')
# Out:
# 8                  Harry Potter and the Half-Blood Prince
# 113             Harry Potter and the Order of the Phoenix
# 191              Harry Potter and the Prisoner of Azkaban
# 197              Harry Potter and the Philosopher's Stone
# 276               Harry Potter and the Chamber of Secrets
# 467                                      Mighty Joe Young
# 1481                       Thunder and the House of Magic
# 37                             Oz: The Great and Powerful
# 109     The Chronicles of Narnia: The Voyage of the Da...
# 143                                                   Pan
# Name: title, dtype: object

# %%
find_rec('Titanic')
# Out:
# 4247            Me You and Five Bucks
# 1081               Revolutionary Road
# 454     The Day the Earth Stood Still
# 961                         The Beach
# 2011                            Cheri
# 4589                           Fabled
# 2915                            Trash
# 1629                Little Black Book
# 3863                           August
# 1311                       Angel Eyes
# Name: title, dtype: object
